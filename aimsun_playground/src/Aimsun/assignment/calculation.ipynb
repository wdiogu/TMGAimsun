# %%
fileName = "C:\\Users\\dioguwil\\Documents\\Williams\\projects\\aimsun_playground\\input_files\\matrices_input.txt"
mtx_id = []
mtx_name = []
lines = []
state = 0
for line in open(fileName, "r").readlines():
    
    # print(line)
    line = line.strip()
    
    if len(line) == 0:
        state = 0
    else:
        if state == 0:
            state = 1
            # read identifier and name
            matrixId = int(line[: line.index(" ")])
            matrixName = line[line.index(" ") + 1 :]
            mtx_name.append(matrixName)
        elif state == 1:

            state = 2
            # read vehicle id and name
            vehId = int(line[: line.index(" ")])
            vehName = line[line.index(" ") + 1 :]
            # lines.append(vehId)
            # mtx_id.append(vehName)
        elif state == 2:
            state = 3
            # From Time
            print("first = ", line)
        elif state == 3:
            state = 4
            # Duration
            print( "second= ", line)
        elif state == 4:
            # Trips
            tokens = line.split(" ")
            # lines.append(tokens)
            # mtx_id.append(len(tokens))
            pass
# Out:
# first =  08:00:00
# second=  01:00:00
# first =  08:00:00
# second=  01:00:00
# first =  08:00:00
# second=  01:00:00
# first =  08:00:00
# second=  01:00:00
# first =  08:00:00
# second=  01:00:00
# first =  08:00:00
# second=  01:00:00
# first =  08:00:00
# second=  01:00:00
# first =  08:00:00
# second=  01:00:00
# first =  08:00:00
# second=  01:00:00
# first =  08:00:00
# second=  01:00:00
# first =  08:00:00
# second=  01:00:00
# first =  08:00:00
# second=  01:00:00
# first =  08:00:00
# second=  01:00:00
# first =  08:00:00
# second=  01:00:00
# first =  08:00:00
# second=  01:00:00
# first =  08:00:00
# second=  01:00:00
# first =  08:00:00
# second=  01:00:00
# first =  08:00:00
# second=  01:00:00
# first =  08:00:00
# second=  01:00:00
# first =  08:00:00
# second=  01:00:00
# first =  08:00:00
# second=  01:00:00
# first =  08:00:00
# second=  01:00:00
# first =  08:00:00
# second=  01:00:00
# first =  08:00:00
# second=  01:00:00
# first =  08:00:00
# second=  01:00:00
# ...

# %%
RED = ('x234114','z8765667')
def globals_lookup(ident):
    return eval(ident)    

t=globals_lookup('RED')
print(t[0])
# Out:
# x234114

# %%
def create_scenario():
    """
    - read traffic plan
    read public transport plan
    read path assignment plan
    read master control plan
    """
    pass


def create_experiment():
    """
    set assignment method
    store path assingment to save_path_assignment_info()
    """
    ...


def save_path_assignment_info():
    """
    set where to save file
    """
    ...


def save_network():
    ...


def _execute(output_file, model, console):
    """
    create scenario
    create experiment
    save path assignment
    run experiment
    """
